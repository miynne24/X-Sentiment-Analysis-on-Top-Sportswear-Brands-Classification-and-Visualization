# %%
import pandas as pd

data=pd.read_csv("Pumadataset.csv")
data.head()
# Out:
#    conversation_id_str                      created_at favorite_count  \
# 0  1762587173642019301  Tue Feb 27 21:15:04 +0000 2024              0
# 1  1762512735126864208  Tue Feb 27 16:19:16 +0000 2024             13
# 2  1762478530292539644  Tue Feb 27 14:03:21 +0000 2024              9
# 3  1762447594909794358  Tue Feb 27 12:00:25 +0000 2024             11
# 4  1762432524075061360  Tue Feb 27 11:00:32 +0000 2024              0
#
#                                            full_text               id_str  \
# 0  Future Pumas! The time is here! Offers are ava...  1762587173642019301
# 1  Today we unbox the @PUMA Fastroid Nitro sneake...  1762512735126864208
# 2  The new A-Style high-end helicopter controller...  1762478530292539644
# 3  The Puma suede is a classic style crafted from...  1762447594909794358
# 4  Are you looking for a clinical modular soundpr...  1762432524075061360
#
#                                          image_url in_reply_to_screen_name  \
# 0  https://pbs.twimg.com/media/GHX3sVQWkAAy0AP.jpg                     NaN
# 1                                              NaN                     NaN
# 2  https://pbs.twimg.com/media/GHWU3NQXEAAou_K.jpg                     NaN
# 3  https://pbs.twimg.com/media/GHV4v2eWYAA-OGH.jpg                     NaN
# 4  https://pbs.twimg.com/media/GHVrCh6WUAADbWf.jpg                     NaN
#
#   lang            location quote_count  reply_count retweet_count  \
# 0   en        Chicago, IL            0          0.0             0
# 1   en           New Tokyo           2          2.0             5
# 2   en  Germany/Europe/USA           1          0.0             0
# 3   en         Bedford, UK           1          0.0             1
# 4   en          Nottingham           0          0.0             0
#
#                                            tweet_url   user_id_str  \
# 0  https://twitter.com/BeNobleJCP/status/17625871...  7.815846e+17
# 1  https://twitter.com/UnboxingWeb3/status/176251...  8.182782e+08
# 2  https://twitter.com/AerosoftGmbH/status/176247...  5.235951e+07
# 3  https://twitter.com/casualclassics/status/1762...  2.564777e+08
# 4  https://twitter.com/hearbuy/status/17624325240...  1.521765e+18
#
#          username
# 0      BeNobleJCP
# 1    UnboxingWeb3
# 2    AerosoftGmbH
# 3  casualclassics
# 4         hearbuy

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14566 entries, 0 to 14565
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      14566 non-null  object
#  1   created_at               14562 non-null  object
#  2   favorite_count           14562 non-null  object
#  3   full_text                14560 non-null  object
#  4   id_str                   14560 non-null  object
#  5   image_url                5713 non-null   object
#  6   in_reply_to_screen_name  3841 non-null   object
#  7   lang                     14560 non-null  object
#  8   location                 8377 non-null   object
#  9   quote_count              14560 non-null  object
#  10  reply_count              14560 non-null  float64
#  11  retweet_count            14560 non-null  object
#  12  tweet_url                14558 non-null  object
#  13  user_id_str              14558 non-null  float64
#  14  username                 14558 non-null  object
# dtypes: float64(2), object(13)
# memory usage: 1.7+ MB

# %%
data.describe()
# Out:
#         reply_count   user_id_str
# count  1.456000e+04  1.455800e+04
# mean   1.394860e+04  7.944071e+17
# std    1.190007e+06  6.934400e+17
# min    0.000000e+00  4.947300e+04
# 25%    0.000000e+00  5.554626e+08
# 50%    0.000000e+00  1.001269e+18
# 75%    1.000000e+00  1.449814e+18
# max    1.015384e+08  1.752607e+18

# %%
#Check Null Values
data.isnull().any()
# Out:
# conversation_id_str        False
# created_at                  True
# favorite_count              True
# full_text                   True
# id_str                      True
# image_url                   True
# in_reply_to_screen_name     True
# lang                        True
# location                    True
# quote_count                 True
# reply_count                 True
# retweet_count               True
# tweet_url                   True
# user_id_str                 True
# username                    True
# dtype: bool

# %%
# Assuming you want to remove rows only if 'text' column has null values
data = data.dropna(subset=['full_text'])

# %%
data.describe()
# Out:
#         reply_count   user_id_str
# count  14558.000000  1.455800e+04
# mean       1.019439  7.944071e+17
# std       15.798722  6.934400e+17
# min        0.000000  4.947300e+04
# 25%        0.000000  5.554626e+08
# 50%        0.000000  1.001269e+18
# 75%        1.000000  1.449814e+18
# max     1518.000000  1.752607e+18

# %%
pip install Image
# Out:
# Requirement already satisfied: Image in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (1.5.33)
# Requirement already satisfied: pillow in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from Image) (10.1.0)
# Requirement already satisfied: django in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from Image) (5.0.3)
# Requirement already satisfied: six in c:\users\asus\appdata\roaming\python\python312\site-packages (from Image) (1.16.0)
# Requirement already satisfied: asgiref<4,>=3.7.0 in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from django->Image) (3.8.1)
# Requirement already satisfied: sqlparse>=0.3.1 in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from django->Image) (0.4.4)
# Requirement already satisfied: tzdata in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from django->Image) (2023.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install WordCloud
# Out:
# Requirement already satisfied: WordCloud in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from WordCloud) (1.26.1)
# Requirement already satisfied: pillow in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from WordCloud) (10.1.0)
# Requirement already satisfied: matplotlib in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from WordCloud) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->WordCloud) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->WordCloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->WordCloud) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->WordCloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib->WordCloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->WordCloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\roaming\python\python312\site-packages (from matplotlib->WordCloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Data Visualization Before Preprocessing
import pandas as pd
import numpy as np
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

df=' '.join(data['full_text'].tolist())

stopwords=set(STOPWORDS)
stopwords.update(['https','co','RT','...','amp'])

wc=WordCloud(stopwords=stopwords, background_color="black", max_words=500, width=800, height=400)

wc.generate(df)

plt.figure(figsize=(10,5))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#Data Visualization Before Preprocessing
import matplotlib.pyplot as plt
from collections import Counter

text=" ".join(data["full_text"])
tokens = text.split()
word_counts= Counter(tokens)

top_words= word_counts.most_common(10)
word, count= zip(*top_words)

colors= plt.cm.Paired(range(len(word)))

plt.figure(figsize=(15, 6))
bars=plt.bar(word, count, color=colors)
plt.xlabel("Word")
plt.ylabel("Count")
plt.title("Most Mentioned Words")
plt.xticks(rotation=45)

for bar, num in zip(bars, count):
    plt.text(bar.get_x()+ bar.get_width()/ 2 - 0.1, num + 1, str(num), fontsize=12, color="black", ha="center")

plt.show()

# %%
#DATA PREPROCESSING
df= pd.DataFrame(data[['created_at','full_text','username']])
df.head(5)
# Out:
#                        created_at  \
# 0  Tue Feb 27 21:15:04 +0000 2024
# 1  Tue Feb 27 16:19:16 +0000 2024
# 2  Tue Feb 27 14:03:21 +0000 2024
# 3  Tue Feb 27 12:00:25 +0000 2024
# 4  Tue Feb 27 11:00:32 +0000 2024
#
#                                            full_text        username
# 0  Future Pumas! The time is here! Offers are ava...      BeNobleJCP
# 1  Today we unbox the @PUMA Fastroid Nitro sneake...    UnboxingWeb3
# 2  The new A-Style high-end helicopter controller...    AerosoftGmbH
# 3  The Puma suede is a classic style crafted from...  casualclassics
# 4  Are you looking for a clinical modular soundpr...         hearbuy

# %%
df.to_csv('Pumadataset_cutcol.csv', index=False)

# %%
#CLEANING
data=pd.read_csv('Pumadataset_cutcol.csv')
data.head(5)
# Out:
#                        created_at  \
# 0  Tue Feb 27 21:15:04 +0000 2024
# 1  Tue Feb 27 16:19:16 +0000 2024
# 2  Tue Feb 27 14:03:21 +0000 2024
# 3  Tue Feb 27 12:00:25 +0000 2024
# 4  Tue Feb 27 11:00:32 +0000 2024
#
#                                            full_text        username
# 0  Future Pumas! The time is here! Offers are ava...      BeNobleJCP
# 1  Today we unbox the @PUMA Fastroid Nitro sneake...    UnboxingWeb3
# 2  The new A-Style high-end helicopter controller...    AerosoftGmbH
# 3  The Puma suede is a classic style crafted from...  casualclassics
# 4  Are you looking for a clinical modular soundpr...         hearbuy

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14560 entries, 0 to 14559
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  14560 non-null  object
#  1   full_text   14560 non-null  object
#  2   username    14558 non-null  object
# dtypes: object(3)
# memory usage: 341.4+ KB

# %%
#remove duplicate data entries
data.drop_duplicates(subset="full_text", keep='first', inplace=True)

# %%
data.info() #to check have duplicates or not
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13834 entries, 0 to 14559
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  13834 non-null  object
#  1   full_text   13834 non-null  object
#  2   username    13833 non-null  object
# dtypes: object(3)
# memory usage: 432.3+ KB

# %%
df= pd.DataFrame(data[['created_at','username','full_text']])
df.head(10)
# Out:
#                        created_at         username  \
# 0  Tue Feb 27 21:15:04 +0000 2024       BeNobleJCP
# 1  Tue Feb 27 16:19:16 +0000 2024     UnboxingWeb3
# 2  Tue Feb 27 14:03:21 +0000 2024     AerosoftGmbH
# 3  Tue Feb 27 12:00:25 +0000 2024   casualclassics
# 4  Tue Feb 27 11:00:32 +0000 2024          hearbuy
# 5  Tue Feb 27 09:40:12 +0000 2024    SneakerScouts
# 6  Tue Feb 27 05:21:57 +0000 2024        JustFittz
# 7  Mon Feb 26 19:01:32 +0000 2024  FootyInfographs
# 8  Mon Feb 26 18:02:43 +0000 2024    theonestophtx
# 9  Mon Feb 26 18:00:29 +0000 2024     Farmstar_Ltd
#
#                                            full_text
# 0  Future Pumas! The time is here! Offers are ava...
# 1  Today we unbox the @PUMA Fastroid Nitro sneake...
# 2  The new A-Style high-end helicopter controller...
# 3  The Puma suede is a classic style crafted from...
# 4  Are you looking for a clinical modular soundpr...
# 5  Dapper Dan x PUMA Suede 'Varsity Green' Availa...
# 6  Puma shades available in our stores. https://t...
# 7  🇲🇽 Hugo Sánchez is perhaps the greatest Mexica...
# 8  2019/2020 Puma Jadon Sancho Dortmund Away Jers...
# 9  𝗠𝗔𝗖𝗛𝗜𝗡𝗘 𝗢𝗙 𝗧𝗛𝗘 𝗪𝗘𝗘𝗞 ‼️ Used Case IH Puma 220 C...

# %%
import re 
import string
import nltk

def remove_URL(tweet):
    url=re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'',tweet)

def remove_mention(tweet):
    return re.sub(r'@\w+', '', tweet)

def remove_html(tweet):
    html=re.compile(r'<.*?>')
    return html.sub(r'',tweet)

def remove_emoji(tweet):
    emoji_pattern=re.compile("["
                             u"\U0001F600-\U0001F64F"
                             u"\U0001F300-\U0001F5FF"
                             u"\U0001F680-\U0001F6FF"
                             u"\U0001F1E0-\U0001F1FF"
                                                 "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'',tweet)

def remove_numbers(tweet):
    tweet= re.sub(r'\d+','',tweet)
    return tweet

def remove_symbols(tweet):
    tweet= re.sub(r'[^a-zA-Z0-9\s]', '',tweet) #Eliminate all symbol
    return tweet

df['cleaning']= df['full_text'].apply(lambda x: remove_URL(x))
df['cleaning']= df['cleaning'].apply(lambda x: remove_html(x))
df['cleaning']= df['cleaning'].apply(lambda x: remove_mention(x))
df['cleaning']= df['cleaning'].apply(lambda x: remove_emoji(x))
df['cleaning']= df['cleaning'].apply(lambda x: remove_symbols(x))
df['cleaning']= df['cleaning'].apply(lambda x: remove_numbers(x))

df.head(5)
# Out:
#                        created_at        username  \
# 0  Tue Feb 27 21:15:04 +0000 2024      BeNobleJCP
# 1  Tue Feb 27 16:19:16 +0000 2024    UnboxingWeb3
# 2  Tue Feb 27 14:03:21 +0000 2024    AerosoftGmbH
# 3  Tue Feb 27 12:00:25 +0000 2024  casualclassics
# 4  Tue Feb 27 11:00:32 +0000 2024         hearbuy
#
#                                            full_text  \
# 0  Future Pumas! The time is here! Offers are ava...
# 1  Today we unbox the @PUMA Fastroid Nitro sneake...
# 2  The new A-Style high-end helicopter controller...
# 3  The Puma suede is a classic style crafted from...
# 4  Are you looking for a clinical modular soundpr...
#
#                                             cleaning
# 0  Future Pumas The time is here Offers are avail...
# 1  Today we unbox the  Fastroid Nitro sneaker wit...
# 2  The new AStyle highend helicopter controllers ...
# 3  The Puma suede is a classic style crafted from...
# 4  Are you looking for a clinical modular soundpr...

# %%
#CASE FOLDING
def case_folding(text):
    if isinstance(text, str):
        lowercase_text=text.lower()
        return lowercase_text
    else:
        return text

df['case_folding']=df['cleaning'].apply(case_folding)
df.head(5)
# Out:
#                        created_at        username  \
# 0  Tue Feb 27 21:15:04 +0000 2024      BeNobleJCP
# 1  Tue Feb 27 16:19:16 +0000 2024    UnboxingWeb3
# 2  Tue Feb 27 14:03:21 +0000 2024    AerosoftGmbH
# 3  Tue Feb 27 12:00:25 +0000 2024  casualclassics
# 4  Tue Feb 27 11:00:32 +0000 2024         hearbuy
#
#                                            full_text  \
# 0  Future Pumas! The time is here! Offers are ava...
# 1  Today we unbox the @PUMA Fastroid Nitro sneake...
# 2  The new A-Style high-end helicopter controller...
# 3  The Puma suede is a classic style crafted from...
# 4  Are you looking for a clinical modular soundpr...
#
#                                             cleaning  \
# 0  Future Pumas The time is here Offers are avail...
# 1  Today we unbox the  Fastroid Nitro sneaker wit...
# 2  The new AStyle highend helicopter controllers ...
# 3  The Puma suede is a classic style crafted from...
# 4  Are you looking for a clinical modular soundpr...
#
#                                         case_folding
# 0  future pumas the time is here offers are avail...
# 1  today we unbox the  fastroid nitro sneaker wit...
# 2  the new astyle highend helicopter controllers ...
# 3  the puma suede is a classic style crafted from...
# 4  are you looking for a clinical modular soundpr...

# %%
#TOKENIZATION
def tokenize(text):
    tokens=text.split()
    return tokens

df['tokenize']=df['case_folding'].apply(tokenize)
df.head(5)
# Out:
#                        created_at        username  \
# 0  Tue Feb 27 21:15:04 +0000 2024      BeNobleJCP
# 1  Tue Feb 27 16:19:16 +0000 2024    UnboxingWeb3
# 2  Tue Feb 27 14:03:21 +0000 2024    AerosoftGmbH
# 3  Tue Feb 27 12:00:25 +0000 2024  casualclassics
# 4  Tue Feb 27 11:00:32 +0000 2024         hearbuy
#
#                                            full_text  \
# 0  Future Pumas! The time is here! Offers are ava...
# 1  Today we unbox the @PUMA Fastroid Nitro sneake...
# 2  The new A-Style high-end helicopter controller...
# 3  The Puma suede is a classic style crafted from...
# 4  Are you looking for a clinical modular soundpr...
#
#                                             cleaning  \
# 0  Future Pumas The time is here Offers are avail...
# 1  Today we unbox the  Fastroid Nitro sneaker wit...
# 2  The new AStyle highend helicopter controllers ...
# 3  The Puma suede is a classic style crafted from...
# 4  Are you looking for a clinical modular soundpr...
#
#                                         case_folding  \
# 0  future pumas the time is here offers are avail...
# 1  today we unbox the  fastroid nitro sneaker wit...
# 2  the new astyle highend helicopter controllers ...
# 3  the puma suede is a classic style crafted from...
# 4  are you looking for a clinical modular soundpr...
#
#                                             tokenize
# 0  [future, pumas, the, time, is, here, offers, a...
# 1  [today, we, unbox, the, fastroid, nitro, sneak...
# 2  [the, new, astyle, highend, helicopter, contro...
# 3  [the, puma, suede, is, a, classic, style, craf...
# 4  [are, you, looking, for, a, clinical, modular,...

# %%
#FILTERING/STOPWORD REMOVAL
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words_id=stopwords.words('indonesian')
stop_words_en=stopwords.words('english')#option
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
# Combine the stopwords lists
combined_stop_words = set(stop_words_id + stop_words_en)

def remove_stopwords(text):
    return[word for word in text if word not in combined_stop_words]
    
df['StopWord Removal']=df['tokenize'].apply(lambda x:remove_stopwords(x))
df.head(5)
# Out:
#                        created_at        username  \
# 0  Tue Feb 27 21:15:04 +0000 2024      BeNobleJCP
# 1  Tue Feb 27 16:19:16 +0000 2024    UnboxingWeb3
# 2  Tue Feb 27 14:03:21 +0000 2024    AerosoftGmbH
# 3  Tue Feb 27 12:00:25 +0000 2024  casualclassics
# 4  Tue Feb 27 11:00:32 +0000 2024         hearbuy
#
#                                            full_text  \
# 0  Future Pumas! The time is here! Offers are ava...
# 1  Today we unbox the @PUMA Fastroid Nitro sneake...
# 2  The new A-Style high-end helicopter controller...
# 3  The Puma suede is a classic style crafted from...
# 4  Are you looking for a clinical modular soundpr...
#
#                                             cleaning  \
# 0  Future Pumas The time is here Offers are avail...
# 1  Today we unbox the  Fastroid Nitro sneaker wit...
# 2  The new AStyle highend helicopter controllers ...
# 3  The Puma suede is a classic style crafted from...
# 4  Are you looking for a clinical modular soundpr...
#
#                                         case_folding  \
# 0  future pumas the time is here offers are avail...
# 1  today we unbox the  fastroid nitro sneaker wit...
# 2  the new astyle highend helicopter controllers ...
# 3  the puma suede is a classic style crafted from...
# 4  are you looking for a clinical modular soundpr...
#
#                                             tokenize  \
# 0  [future, pumas, the, time, is, here, offers, a...
# 1  [today, we, unbox, the, fastroid, nitro, sneak...
# 2  [the, new, astyle, highend, helicopter, contro...
# 3  [the, puma, suede, is, a, classic, style, craf...
# 4  [are, you, looking, for, a, clinical, modular,...
#
#                                     StopWord Removal
# 0  [future, pumas, time, offers, available, join,...
# 1  [today, unbox, fastroid, nitro, sneaker, avail...
# 2  [new, astyle, highend, helicopter, controllers...
# 3  [puma, suede, classic, style, crafted, rich, s...
# 4  [looking, clinical, modular, soundproof, booth...

# %%
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in c:\users\asus\appdata\local\programs\python\python312\lib\site-packages (1.0.1)

# %%
#STEMMING
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
factory=StemmerFactory()
stemmer=factory.create_stemmer()

def stem_text(text):
    return[stemmer.stem(word) for word in text]

df['stemming_data']= df['StopWord Removal'].apply(lambda x: ' '.join(stem_text(x)))

df.head(5)
# Out:
#                        created_at        username  \
# 0  Tue Feb 27 21:15:04 +0000 2024      BeNobleJCP
# 1  Tue Feb 27 16:19:16 +0000 2024    UnboxingWeb3
# 2  Tue Feb 27 14:03:21 +0000 2024    AerosoftGmbH
# 3  Tue Feb 27 12:00:25 +0000 2024  casualclassics
# 4  Tue Feb 27 11:00:32 +0000 2024         hearbuy
#
#                                            full_text  \
# 0  Future Pumas! The time is here! Offers are ava...
# 1  Today we unbox the @PUMA Fastroid Nitro sneake...
# 2  The new A-Style high-end helicopter controller...
# 3  The Puma suede is a classic style crafted from...
# 4  Are you looking for a clinical modular soundpr...
#
#                                             cleaning  \
# 0  Future Pumas The time is here Offers are avail...
# 1  Today we unbox the  Fastroid Nitro sneaker wit...
# 2  The new AStyle highend helicopter controllers ...
# 3  The Puma suede is a classic style crafted from...
# 4  Are you looking for a clinical modular soundpr...
#
#                                         case_folding  \
# 0  future pumas the time is here offers are avail...
# 1  today we unbox the  fastroid nitro sneaker wit...
# 2  the new astyle highend helicopter controllers ...
# 3  the puma suede is a classic style crafted from...
# 4  are you looking for a clinical modular soundpr...
#
#                                             tokenize  \
# 0  [future, pumas, the, time, is, here, offers, a...
# 1  [today, we, unbox, the, fastroid, nitro, sneak...
# 2  [the, new, astyle, highend, helicopter, contro...
# 3  [the, puma, suede, is, a, classic, style, craf...
# 4  [are, you, looking, for, a, clinical, modular,...
#
#                                     StopWord Removal  \
# 0  [future, pumas, time, offers, available, join,...
# 1  [today, unbox, fastroid, nitro, sneaker, avail...
# 2  [new, astyle, highend, helicopter, controllers...
# 3  [puma, suede, classic, style, crafted, rich, s...
# 4  [looking, clinical, modular, soundproof, booth...
#
#                                        stemming_data
# 0  future pumas time offers available join jcp fa...
# 1  today unbox fastroid nitro sneaker available e...
# 2  new astyle highend helicopter controllers pro ...
# 3  puma suede classic style crafted rich suede fe...
# 4  looking clinical modular soundproof booth puma...

# %%
from nltk.stem import WordNetLemmatizer

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

def lemmatize_tokenize(text):
    # Tokenize the text into words
    tokens = word_tokenize(text)
    # Lemmatize each word in the tokens list
    lemmatized_words = [lemmatizer.lemmatize(word) for word in tokens]
    # Return the list of lemmatized words
    return lemmatized_words

# Example usage:
df['lemmatized_tokens'] = df['stemming_data'].apply(lemmatize_tokenize)
df.head(5)
# Out:
#                        created_at        username  \
# 0  Tue Feb 27 21:15:04 +0000 2024      BeNobleJCP
# 1  Tue Feb 27 16:19:16 +0000 2024    UnboxingWeb3
# 2  Tue Feb 27 14:03:21 +0000 2024    AerosoftGmbH
# 3  Tue Feb 27 12:00:25 +0000 2024  casualclassics
# 4  Tue Feb 27 11:00:32 +0000 2024         hearbuy
#
#                                            full_text  \
# 0  Future Pumas! The time is here! Offers are ava...
# 1  Today we unbox the @PUMA Fastroid Nitro sneake...
# 2  The new A-Style high-end helicopter controller...
# 3  The Puma suede is a classic style crafted from...
# 4  Are you looking for a clinical modular soundpr...
#
#                                             cleaning  \
# 0  Future Pumas The time is here Offers are avail...
# 1  Today we unbox the  Fastroid Nitro sneaker wit...
# 2  The new AStyle highend helicopter controllers ...
# 3  The Puma suede is a classic style crafted from...
# 4  Are you looking for a clinical modular soundpr...
#
#                                         case_folding  \
# 0  future pumas the time is here offers are avail...
# 1  today we unbox the  fastroid nitro sneaker wit...
# 2  the new astyle highend helicopter controllers ...
# 3  the puma suede is a classic style crafted from...
# 4  are you looking for a clinical modular soundpr...
#
#                                             tokenize  \
# 0  [future, pumas, the, time, is, here, offers, a...
# 1  [today, we, unbox, the, fastroid, nitro, sneak...
# 2  [the, new, astyle, highend, helicopter, contro...
# 3  [the, puma, suede, is, a, classic, style, craf...
# 4  [are, you, looking, for, a, clinical, modular,...
#
#                                     StopWord Removal  \
# 0  [future, pumas, time, offers, available, join,...
# 1  [today, unbox, fastroid, nitro, sneaker, avail...
# 2  [new, astyle, highend, helicopter, controllers...
# 3  [puma, suede, classic, style, crafted, rich, s...
# 4  [looking, clinical, modular, soundproof, booth...
#
#                                        stemming_data  \
# 0  future pumas time offers available join jcp fa...
# 1  today unbox fastroid nitro sneaker available e...
# 2  new astyle highend helicopter controllers pro ...
# 3  puma suede classic style crafted rich suede fe...
# 4  looking clinical modular soundproof booth puma...
#
#                                      lemmatized_text  \
# 0  future puma time offer available join jcp fami...
# 1  today unbox fastroid nitro sneaker available e...
# 2  new astyle highend helicopter controller pro f...
# 3  puma suede classic style crafted rich suede fe...
# 4  looking clinical modular soundproof booth puma...
#
#                                    lemmatized_tokens
# 0  [future, puma, time, offer, available, join, j...
# 1  [today, unbox, fastroid, nitro, sneaker, avail...
# 2  [new, astyle, highend, helicopter, controller,...
# 3  [puma, suede, classic, style, crafted, rich, s...
# 4  [looking, clinical, modular, soundproof, booth...

# %%
#EXPORT TO CSV
df.to_csv('Pumadataset_cleaned.csv', encoding='utf8', index=False)

# %%
#VISUALIZATION AFTER PREPROCESSING
df=pd.read_csv('Pumadataset_cleaned.csv')
df.tail(5)
# Out:
#                            created_at        username  \
# 13829  Tue Nov 14 03:42:37 +0000 2023  malaysiandaily
# 13830  Tue Nov 14 03:42:26 +0000 2023  malaysiandaily
# 13831  Tue Nov 14 03:42:15 +0000 2023  malaysiandaily
# 13832  Tue Nov 14 03:42:00 +0000 2023  malaysiandaily
# 13833  Mon Nov 13 22:51:48 +0000 2023  JessiJones3701
#
#                                                full_text  \
# 13829  Check out PUMA Unisex Redeem Profoam Running S...
# 13830  Check out [NEW] PUMA Carina Leather Women's Sh...
# 13831  Check out [NEW] PUMA Retaliate Tongue Men's Ru...
# 13832  Check out [NEW] PUMA Retaliate Tongue Men's Ru...
# 13833  Ever aware any good. Your future is a weapon w...
#
#                                                 cleaning  \
# 13829  Check out PUMA Unisex Redeem Profoam Running S...
# 13830  Check out NEW PUMA Carina Leather Womens Shoes...
# 13831  Check out NEW PUMA Retaliate Tongue Mens Runni...
# 13832  Check out NEW PUMA Retaliate Tongue Mens Runni...
# 13833  Ever aware any good Your future is a weapon wh...
#
#                                             case_folding  \
# 13829  check out puma unisex redeem profoam running s...
# 13830  check out new puma carina leather womens shoes...
# 13831  check out new puma retaliate tongue mens runni...
# 13832  check out new puma retaliate tongue mens runni...
# 13833  ever aware any good your future is a weapon wh...
#
#                                                 tokenize  \
# 13829  ['check', 'out', 'puma', 'unisex', 'redeem', '...
# 13830  ['check', 'out', 'new', 'puma', 'carina', 'lea...
# 13831  ['check', 'out', 'new', 'puma', 'retaliate', '...
# 13832  ['check', 'out', 'new', 'puma', 'retaliate', '...
# 13833  ['ever', 'aware', 'any', 'good', 'your', 'futu...
#
#                                         StopWord Removal  \
# 13829  ['check', 'puma', 'unisex', 'redeem', 'profoam...
# 13830  ['check', 'new', 'puma', 'carina', 'leather', ...
# 13831  ['check', 'new', 'puma', 'retaliate', 'tongue'...
# 13832  ['check', 'new', 'puma', 'retaliate', 'tongue'...
# 13833  ['ever', 'aware', 'good', 'future', 'weapon', ...
#
#                                            stemming_data  \
# 13829  check puma unisex redeem profoam running shoes...
# 13830  check new puma carina leather womens shoes whi...
# 13831  check new puma retaliate tongue mens running s...
# 13832  check new puma retaliate tongue mens running s...
# 13833  ever aware good future weapon whose ampxampxam...
#
#                                          lemmatized_text  \
# 13829  check puma unisex redeem profoam running shoe ...
# 13830  check new puma carina leather woman shoe white...
# 13831  check new puma retaliate tongue men running sh...
# 13832  check new puma retaliate tongue men running sh...
# 13833  ever aware good future weapon whose ampxampxam...
#
#                                        lemmatized_tokens
# 13829  ['check', 'puma', 'unisex', 'redeem', 'profoam...
# 13830  ['check', 'new', 'puma', 'carina', 'leather', ...
# 13831  ['check', 'new', 'puma', 'retaliate', 'tongue'...
# 13832  ['check', 'new', 'puma', 'retaliate', 'tongue'...
# 13833  ['ever', 'aware', 'good', 'future', 'weapon', ...

# %%
#VISUALIZATION AFTER PREPROCESSING
import pandas as pd
import numpy as np
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

text=' '.join(df['lemmatized_text'].apply(lambda x: str(x) if isinstance(x, (str, int, float)) else ''))

wordcloud=WordCloud(width=800,height=400, background_color='black').generate(text)


plt.figure(figsize=(10,5))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import matplotlib.pyplot as plt
from collections import Counter

text=" ".join(df["lemmatized_text"].apply(lambda x:str(x) if isinstance(x, (str,int, float)) else ''))
tokens = text.split()
word_counts= Counter(tokens)

top_words= word_counts.most_common(10)
word, count= zip(*top_words)

colors= plt.cm.Paired(range(len(word)))

plt.figure(figsize=(15, 6))
bars=plt.bar(word, count, color=colors)
plt.xlabel("Word")
plt.ylabel("Count")
plt.title("Most Mentioned Words")
plt.xticks(rotation=45)

for bar, num in zip(bars, count):
    plt.text(bar.get_x()+ bar.get_width()/ 2 - 0.1, num + 1, str(num), fontsize=12, color="black", ha="center")

plt.show()
